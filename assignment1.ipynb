# %% [markdown]
# ## <center>  <b> NLP Navigator - Assignment 1 </b>  </center>

# %% [markdown]
# This is the first assignment of the project and will test your basic python skills and what you have learnt so far about the libraries like numpy and matplotlib. The problem statement and your tasks are described below. You have to rename the notebook as `{Your Name}_Assignment1.ipynb` and write all the code and then generate outputs in it. Submission will be on github and more guidelines will be given soon. The deadline to submit the assignment is `10th June 5:00 PM`

# %% [markdown]
# Given a set of $ n $ points in $ d $ dimensional Euclidean Space, we will find all pairs of points whose Euclidean distance is less than $ r $.
#
# Let  $ \overrightarrow{P_1} = (P_{11},P_{12}, \ldots, P_{1d}) $ and $ \overrightarrow{P_2} = (P_{21},P_{22}, \ldots, P_{2d}) $ be two points. Then the Euclidean distance between them is equal to the norm $ \left|\left| \overrightarrow{P_1} - \overrightarrow{P_2} \right|\right| $.
#
# We have to find the set $ A = \left\{(i, j): \left|\left| \overrightarrow{P_1} - \overrightarrow{P_2} \right|\right| \leq r \right\} $ where $ i,j \in \{1,2,3,...,n\} $.
#
#
# Obviously we can find it by using 2 nested loops and searching over all pairs, but we will do the task in an optimised way. Let us make a grid where each cell is of dimension $ r \times r $. Then, (say d = 2)
#
# ![graph1](https://drive.google.com/uc?export=view&id=1qIcPgkv9Q3fI-eV5AaAobjFIYy_2siZN)
#
# Divide the points into the cells based on their coordinates. For example, say $ 4 $ points $ \left( \frac{1}{2}, \frac{2}{3} \right), \left( \frac{2}{3}, \frac{3}{2} \right), \left( 1, 1 \right), \left( \frac{3}{2}, \frac{5}{2} \right) $ and $ r = 1 $. So the division should be like -
#
# ![graph2](https://drive.google.com/uc?export=view&id=1-u-mT1PTxOkow_uz0T8ZBjU35u63uU7F)
#
# Now comes the observation: For any point, the points which are within distance $ d $ from it must lie in 8 adjacent cells and no where else. So, for every point, just search the points present in 8 adjacent cells, and add the valid pairs to the answer set $ A $. Please note that for corner cells, the number of adjacent cells will not be equal to 8. So, write your code including those cases also.
# ##### Some points for higher dimension cases:
# 1. Think whether the number of adjacent cells for higher dimensions will be 8 or more (or less).
# 2. Observe that the dimension of each cell will not be $r*r$ for each case.
# ##### <u>Note</u>: Assume the pair $ (i,j) $ and $ (j,i) $ to be same. So write your code accordingly. For example, in 2-D space, we will count $ ((1,2), (4,5)) $ and $ ((4,5), (1,2)) $ only once.

# %% [markdown]
# ## Tasks TO DO:
#
# 1. Generate a set of $ 1000 $ random points in $ 2 $ dimensional space with coordinates ranging between 0 and 100.
# 2. For $ r = \{ 1, 2, \ldots, 10 \} $, divide the points into grid as shown.
#    - Show using matplotlib the various points using different colours.
#    - Find pairs and store them in a list/set $ A $
# 3. Do task 1 and 2 for $ d = 3, 4, 10, 50, 100 $ (except plotting) and store the results.
# (You can also plot for $ d = 3 $ but it is optional)

# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import product

# Function to find the norm
def euclidean_distance(point1, point2):
    return np.linalg.norm(point1 - point2)

# Function to find pair of points within given distance
def find_pairs_within_distance(points, r):
    n = len(points)
    cell_indices = np.floor(points / r).astype(int)
    cell_dict = {}

    for i, idx in enumerate(cell_indices):
        if tuple(idx) not in cell_dict:
            cell_dict[tuple(idx)] = []
        cell_dict[tuple(idx)].append(i)

    pairs = set()

    for i, point in enumerate(points):
        idx = cell_indices[i]
        neighbor_cells = np.array(np.meshgrid(*[range(i-1, i+2) for i in idx])).T.reshape(-1, len(idx))
        valid_neighbor_cells = neighbor_cells[np.all((0 <= neighbor_cells) & (neighbor_cells < np.ceil(100/r)), axis=1)]
        
        for cell in valid_neighbor_cells:
            if tuple(cell) in cell_dict:
                for idx in cell_dict[tuple(cell)]:
                    if idx != i and np.linalg.norm(point - points[idx]) < r:
                        pairs.add(tuple(sorted((tuple(point), tuple(points[idx])))))

    return pairs


# Function to generate random points in 2D space (float values)
def generate_random_points(num_points, min_val, max_val,dimension):
    points = np.random.uniform(min_val, max_val, size=(num_points, dimension))
    return points

# Function to plot the points and grid
def plot_points_with_grid(points, r):
    plt.figure(figsize=(35,20))
    plt.scatter(points[:, 0], points[:, 1], c=np.arange(len(points)), cmap='viridis')
    plt.colorbar(label='Point Index')
    plt.title('Scatter Plot of Points in 2D Space')
    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.grid(True)  # Show gridlines

    # Creating gridlines at a distance of r
    x_min, x_max = min(points[:, 0]), max(points[:, 0])
    y_min, y_max = min(points[:, 1]), max(points[:, 1])
    x_grid = np.arange(np.floor(x_min / r) * r, np.ceil(x_max / r) * r + r, r)  # Adjusted range for x-axis
    y_grid = np.arange(np.floor(y_min / r) * r, np.ceil(y_max / r) * r + r, r)  # Adjusted range for y-axis
    plt.xticks(x_grid)
    plt.yticks(y_grid)
    plt.show() # Display the plot
    return points

# Input parameters
num_points = 1000
min_val, max_val = 1.0, 100.0
distance_r = 1 # Set the distance for gridlines
dimension=2

# Generate random points in 2D space with float values
random_points = generate_random_points(num_points, min_val, max_val,dimension)
#print(random_points)

# Plotting the points and grid for 2D
if(dimension==2):
    points = plot_points_with_grid(random_points, distance_r)

# Find unique pairs of points within distance r
pairs_within_distance_r = find_pairs_within_distance(random_points, distance_r)
print("Pairs within distance r:")
for pair in pairs_within_distance_r:
    print(pair)  # Printing unique pairs of points
# Out:
# Pairs within distance r:
# ((92.1266113835448, 19.513517426551804), (93.00153339486376, 19.130066869460382))
# ((21.991904096401562, 45.055664439373466), (22.191783830620267, 45.781474223547654))
# ((29.267319789633046, 7.2524767787054625), (29.267740778247216, 7.158534645010677))
# ((61.33587900086243, 41.633819554815744), (61.99424602199279, 40.954463019606955))
# ((46.67377475129578, 93.56884988211849), (46.83860004466716, 93.18482777059607))
# ((83.08631519230923, 5.790256569165084), (83.17290594445996, 6.101710838574911))
# ((66.50312506208768, 86.53706998502014), (67.35779873334369, 86.16229466439692))
# ((7.366179606149939, 73.80668662378972), (7.907186345728311, 73.28265856358189))
# ((72.32609284530162, 38.59931505834387), (72.57439414733331, 38.40659830130278))
# ((44.676208312892875, 24.574985359419514), (45.20574166093343, 24.16315737785013))
# ((29.51698411986987, 39.42486147085931), (29.698638476105106, 38.67524551683139))
# ((79.81266555836805, 42.370340888431926), (80.30275312128262, 42.85472846922583))
# ((92.43319106580667, 25.065993968997137), (92.86175633967312, 25.842672609006875))
# ((83.560976087245, 22.71471036547625), (83.58044456639304, 21.901038600348574))
# ((43.75176217267751, 45.479842539002874), (43.86728441749803, 45.4232030789265))
# ((29.267740778247216, 7.158534645010677), (29.286810741033054, 6.482314525118357))
# ((93.4987828749534, 95.81625450668815), (93.85221578671128, 95.28000174645095))
# ((41.17537813195562, 47.55505682281586), (41.550405523327704, 47.17596157610339))
# ((98.17015348930022, 93.24994671971336), (98.63288748167595, 93.48156328004508))
# ((56.92327302516977, 76.1307913818454), (57.51341055378115, 76.38527149634706))
# ((4.272441095297918, 31.301920506552726), (4.474291465883511, 30.909799251144413))
# ((1.9526278805112973, 44.152100854780926), (2.376767304316762, 44.10440362254129))
# ((6.1534524681340015, 70.5105992389346), (6.9857547660010635, 70.84061866553861))
# ((77.36970747646077, 18.41793919026791), (77.59742414465879, 19.039336545533086))
# ((32.489944067677754, 37.36049449719434), (33.30958223828507, 37.10726490932912))
# ((87.05266343515915, 82.17799372833292), (87.38499497293535, 81.76529887224935))
# ((42.000035753001335, 8.616505620053456), (42.25566542787558, 9.45627422369672))
# ((83.08631519230923, 5.790256569165084), (83.52417651569463, 5.123165608946385))
# ((88.3540045429193, 19.424102862151706), (88.66987428959223, 19.10586694473639))
# ((16.22908913597772, 89.04759860750953), (16.398500451411678, 89.05127285199205))
# ((61.54222594899692, 5.061519449318383), (61.59195343913651, 4.48287733425672))
# ((93.5887395439503, 6.6506416347011035), (93.98053706670517, 5.891315593263588))
# ((43.39148936755091, 32.20184615679333), (44.0746636735455, 31.51186399730707))
# ((7.446484266161317, 94.5789759272626), (8.066310795658838, 94.94552949854439))
# ((98.80042751272903, 57.34359271421456), (99.6546314353225, 57.102290278326244))
# ((78.45427847742572, 17.885595165177886), (78.58258131505617, 18.41415943099308))
# ((48.81867161024711, 26.806760182845913), (49.00954220377615, 26.010277656974516))
# ((58.88906052025226, 96.86023102737695), (59.53412173426073, 96.23841510916412))
# ((11.278281797477568, 55.90426723254339), (11.765865152753411, 56.14953681799465))
# ((41.17537813195562, 47.55505682281586), (41.21583579183236, 47.56367361110212))
# ((43.639532481913626, 32.00502187024139), (44.0746636735455, 31.51186399730707))
# ((5.0850112733614585, 78.76025677326412), (5.214524506085449, 78.51482557914254))
# ((58.66808211219065, 82.13083414260727), (59.38876768765893, 81.78541560675119))
# ((31.375807936112505, 77.90912042872573), (32.061636370788136, 78.0734787810885))
# ((41.21583579183236, 47.56367361110212), (41.550405523327704, 47.17596157610339))
# ((36.953397557565985, 85.13829636576442), (37.40239977909471, 84.5376849735701))
# ((62.00443137378808, 66.49729675135761), (62.30488105232979, 65.58778982908827))
# ((45.92547985067227, 83.8039217812659), (46.06166250189481, 83.18485390760397))
# ((52.33295961420632, 37.24896479951213), (53.05645523876026, 37.576574205617284))
# ((22.106484100470855, 20.18972272357337), (22.932174577970226, 20.61035890850933))
# ((13.693570684076102, 82.83974487183929), (14.554983588509092, 83.32031250834395))
# ((85.9586762021695, 21.631378117454823), (86.0216424805185, 21.62021070813575))
# ((60.77748357752007, 42.37237685839816), (61.33587900086243, 41.633819554815744))
# ((38.80340397434305, 42.889302568699854), (39.62436585645921, 42.523236184884354))
# ((20.998294103316887, 34.01980017393992), (21.583126688631467, 34.29472198234525))
# ((78.58258131505617, 18.41415943099308), (78.78887379985642, 19.250522087936663))
# ((86.26304502198663, 66.65185946518648), (86.85512375739665, 66.39191050160456))
# ((14.944942870490891, 85.84204341096276), (15.70768359445455, 85.31448433191966))
# ((82.17855684001019, 38.114385988137606), (82.27773669304518, 39.08219223224951))
# ((87.03672040726407, 82.98854922713751), (87.05266343515915, 82.17799372833292))
# ((53.253633911706316, 12.28607147696732), (53.3195359229392, 12.498735960618879))
# ((67.00442000745625, 66.01995681937225), (67.40728118138534, 65.34983331714014))
# ((57.48842544394263, 15.297146855964794), (58.086854796231485, 15.028069429744662))
# ((71.44784930986232, 87.05100746127671), (71.79529654058544, 87.26752467784533))
# ((87.23689484286943, 20.483689423838335), (87.37838377504235, 19.72368942050398))
# ((5.651615512285728, 26.00241840475871), (6.155038738297661, 26.738473426401193))
# ((6.161513152622491, 73.31696572153368), (6.76539451442422, 72.81638069007084))
# ((19.047843595914912, 94.0617679677475), (19.37090872342187, 93.96848638332861))
# ((40.929994580328184, 37.655009717301894), (41.826231709780544, 37.59145293029896))
# ((72.60966873248547, 51.57172297424189), (73.25292150930589, 50.92458653606789))
# ((41.04161473224751, 22.123667379426855), (41.52396178968792, 22.6437529942812))
# ((83.08631519230923, 5.790256569165084), (83.21261547506666, 5.5576038109046815))
# ((91.78509287470267, 50.88182037059823), (92.28915425988279, 50.09986422945864))
# ((59.84460995206703, 74.75647814543565), (59.97009198469122, 74.48155107556796))
# ((69.32880621596686, 66.7422960807259), (69.67591424911151, 67.49106185821793))
# ((22.502540020242492, 54.959017035535766), (23.272365926713782, 55.070068343526934))
# ((37.82156897408704, 69.60978563553918), (38.59272970858663, 69.157244294409))
# ((22.106484100470855, 20.18972272357337), (22.423591668729834, 20.992507104396182))
# ((41.826231709780544, 37.59145293029896), (42.55139663775065, 37.86399374373298))
# ((93.68322216061932, 64.92438478541895), (94.49485945396414, 64.71976337469758))
# ((67.3638802242045, 43.49125120964258), (67.49231054635273, 44.39876321898737))
# ((94.60224972761267, 85.77912663797068), (95.29293203579678, 85.30309464367635))
# ((16.678177915031583, 66.60751245765428), (16.727685419864535, 67.31649574671108))
# ((29.267319789633046, 7.2524767787054625), (29.286810741033054, 6.482314525118357))
# ((83.03700849067818, 3.220234364980616), (83.1333664661332, 3.221194633950919))
# ((29.766923984932415, 77.50666250547215), (30.117588071937593, 77.56460724120974))
# ((40.53998085864895, 52.1265104772438), (41.142003447311275, 51.45642028878472))
# ((57.79086614251126, 47.62945910414244), (58.15581040703827, 47.503390059363745))
# ((22.423591668729834, 20.992507104396182), (22.932174577970226, 20.61035890850933))
# ((24.519412391186304, 43.1992389813095), (25.19979396438988, 43.856324856375494))
# ((94.18945052386424, 4.014944417704372), (94.72814857320766, 3.560186701844131))
# ((48.08873488010359, 33.76831552715244), (48.90977261064169, 34.26816298836556))
# ((47.842108476194646, 34.26514771144334), (48.08873488010359, 33.76831552715244))
# ((47.16276644046094, 19.905447713037788), (47.578292150492636, 20.11256724742408))
# ((5.214524506085449, 78.51482557914254), (5.438880347715865, 78.33467614161606))
# ((69.32880621596686, 66.7422960807259), (69.56828470056534, 65.96423676338746))
# ((77.65467392566192, 6.504922876837699), (77.83752509453788, 5.57362169479155))
# ((26.909014091124913, 28.921220309297226), (27.444976385714092, 29.477392386697627))
# ((11.278281797477568, 55.90426723254339), (11.48745208160398, 56.6367242032645))
# ((93.22425322674758, 65.19642662033299), (93.68322216061932, 64.92438478541895))
# ((93.16182952746641, 72.34091982202011), (93.94598503202103, 72.33042760532048))
# ((1.60793969833224, 24.001315797648793), (1.6768500455190143, 24.626339358696725))
# ((29.600390155893244, 77.35587759669686), (30.117588071937593, 77.56460724120974))
# ((96.76579830347569, 96.369353185127), (97.15231820641125, 96.73750646240318))
# ((27.139333103436933, 70.07949813493732), (28.05968431989753, 70.05309052886689))
# ((43.26214948744992, 76.57354598810242), (44.11826155570484, 76.67356779094202))
# ((14.944942870490891, 85.84204341096276), (15.400988908578778, 85.34246761886703))
# ((87.05266343515915, 82.17799372833292), (87.61445633908212, 81.73756074036469))
# ((71.31020258068327, 69.75261000056288), (71.82541049310983, 69.8168720284953))
# ((95.41187689828264, 79.32155798514052), (95.4718534955696, 78.63491817429822))
# ((83.17290594445996, 6.101710838574911), (83.21261547506666, 5.5576038109046815))
# ((92.86175633967312, 25.842672609006875), (93.0819842211165, 24.91639460717798))
# ((98.41087163533703, 21.236951329878583), (98.76702390706905, 21.418339221068365))
# ((89.785922410584, 50.840408845130526), (90.0116138754868, 51.05087775095202))
# ((28.931562785443717, 17.266627167340083), (29.31042518605363, 18.12501113240849))
# ((32.365892350102655, 96.62296864681825), (32.93506250157431, 95.89366101058755))
# ((81.97092619880578, 37.59973500086916), (82.17855684001019, 38.114385988137606))
# ((3.280249374607455, 21.026682955480414), (3.5898503368194574, 21.746626425729843))
# ((24.718737059311316, 33.088223306866254), (24.790163896941852, 32.9139018927347))
# ((31.141404429935633, 64.03284779781652), (32.039477999486, 64.27330374099482))
# ((15.400988908578778, 85.34246761886703), (15.70768359445455, 85.31448433191966))
# ((81.01206686819212, 93.43038186007794), (81.17953562784786, 93.11982259042834))
# ((8.49824410303201, 3.650581212796162), (9.119350961005317, 3.8936076523886034))
# ((86.84924775739779, 90.43024681362255), (87.60924275303105, 90.41643353340685))
# ((49.96315101099985, 9.203341893123541), (50.6637439235372, 8.871061329596984))
# ((27.139333103436933, 70.07949813493732), (28.024541939571247, 69.75593982367403))
# ((94.81197898354245, 34.003499543400714), (95.01358155065662, 34.3231843721513))
# ((87.38499497293535, 81.76529887224935), (87.61445633908212, 81.73756074036469))
# ((58.88906052025226, 96.86023102737695), (58.896618835752875, 97.82139925809949))
# ((73.56886225221243, 39.60829386371205), (73.91498356203928, 39.6368606398408))
# ((37.26372542070863, 84.53678714119263), (37.40239977909471, 84.5376849735701))
# ((7.548695163145486, 76.3970877179687), (7.5781586389124485, 76.80648843537001))
# ((21.746576498662574, 27.90264084579567), (21.876291694568433, 28.39221857549189))
# ((8.213894923876527, 69.57934728070224), (8.52840024243722, 68.9542973220127))
# ((56.263019966640755, 42.05046604494684), (56.81631280080368, 41.522183698647716))
# ((56.91956326520448, 70.32957059576496), (57.09216762364799, 71.29396829642462))
# ((11.48745208160398, 56.6367242032645), (11.765865152753411, 56.14953681799465))
# ((68.54432136207006, 33.560712694189895), (69.01923331410045, 34.4336551202929))
# ((16.678177915031583, 66.60751245765428), (17.11532076483559, 65.72640368734386))
# ((30.488555868135983, 58.27361179997594), (30.497033138478002, 57.684768023386866))
# ((21.26067477897177, 81.58988763560461), (21.451677740666483, 81.01125910649897))
# ((85.76364117379259, 75.96000723948286), (86.04265221794209, 75.56329489842547))
# ((52.57824300232873, 22.402192170016324), (52.637730794257976, 22.411535766396334))
# ((20.85610954520247, 27.586372764010466), (21.746576498662574, 27.90264084579567))
# ((36.953397557565985, 85.13829636576442), (37.26372542070863, 84.53678714119263))
# ((43.39148936755091, 32.20184615679333), (43.639532481913626, 32.00502187024139))
# ((53.50970117766075, 48.7085315682171), (53.7280187391522, 48.46395103386351))
# ((86.61200930870429, 25.442680403729323), (86.72276634734389, 26.347307864643064))
# ((5.0850112733614585, 78.76025677326412), (5.438880347715865, 78.33467614161606))
# ((92.43319106580667, 25.065993968997137), (93.0819842211165, 24.91639460717798))
# ((30.18027817900162, 53.919330100505675), (30.64783252885466, 53.22906121021479))
# ((19.42954727202895, 33.87944710057376), (19.527929096213942, 34.551385939723566))
# ((88.86118436247645, 23.523201053325856), (89.55949029862748, 23.56937204086116))
# ((1.714909867699039, 38.72712657963286), (2.5164788618570957, 39.023407591290564))
# ((97.74712105345527, 35.347341203754894), (97.96618801379864, 35.56094788912437))
# ((28.024541939571247, 69.75593982367403), (28.05968431989753, 70.05309052886689))
# ((54.811043597442904, 25.560396477558605), (55.01453674666669, 26.441099681619885))
# ((24.161793631794417, 40.06996487003992), (24.648316420423086, 40.79972925537442))
# ((35.799297043638305, 91.51509478371518), (36.470071237397306, 91.77685060522263))
# ((94.51870842917232, 86.68043986120458), (94.60224972761267, 85.77912663797068))
# ((83.21261547506666, 5.5576038109046815), (83.52417651569463, 5.123165608946385))
# ((26.07068248030204, 29.006088907045843), (26.909014091124913, 28.921220309297226))
# ((29.600390155893244, 77.35587759669686), (29.766923984932415, 77.50666250547215))
# ((58.78762273975705, 4.993871715788881), (59.55253436388202, 4.731045531874668))
