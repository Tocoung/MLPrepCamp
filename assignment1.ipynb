# %% [markdown]
# ## <center>  <b> NLP Navigator - Assignment 1 </b>  </center>

# %% [markdown]
# This is the first assignment of the project and will test your basic python skills and what you have learnt so far about the libraries like numpy and matplotlib. The problem statement and your tasks are described below. You have to rename the notebook as `{Your Name}_Assignment1.ipynb` and write all the code and then generate outputs in it. Submission will be on github and more guidelines will be given soon. The deadline to submit the assignment is `10th June 5:00 PM`

# %% [markdown]
# Given a set of $ n $ points in $ d $ dimensional Euclidean Space, we will find all pairs of points whose Euclidean distance is less than $ r $.
#
# Let  $ \overrightarrow{P_1} = (P_{11},P_{12}, \ldots, P_{1d}) $ and $ \overrightarrow{P_2} = (P_{21},P_{22}, \ldots, P_{2d}) $ be two points. Then the Euclidean distance between them is equal to the norm $ \left|\left| \overrightarrow{P_1} - \overrightarrow{P_2} \right|\right| $.
#
# We have to find the set $ A = \left\{(i, j): \left|\left| \overrightarrow{P_1} - \overrightarrow{P_2} \right|\right| \leq r \right\} $ where $ i,j \in \{1,2,3,...,n\} $.
#
#
# Obviously we can find it by using 2 nested loops and searching over all pairs, but we will do the task in an optimised way. Let us make a grid where each cell is of dimension $ r \times r $. Then, (say d = 2)
#
# ![graph1](https://drive.google.com/uc?export=view&id=1qIcPgkv9Q3fI-eV5AaAobjFIYy_2siZN)
#
# Divide the points into the cells based on their coordinates. For example, say $ 4 $ points $ \left( \frac{1}{2}, \frac{2}{3} \right), \left( \frac{2}{3}, \frac{3}{2} \right), \left( 1, 1 \right), \left( \frac{3}{2}, \frac{5}{2} \right) $ and $ r = 1 $. So the division should be like -
#
# ![graph2](https://drive.google.com/uc?export=view&id=1-u-mT1PTxOkow_uz0T8ZBjU35u63uU7F)
#
# Now comes the observation: For any point, the points which are within distance $ d $ from it must lie in 8 adjacent cells and no where else. So, for every point, just search the points present in 8 adjacent cells, and add the valid pairs to the answer set $ A $. Please note that for corner cells, the number of adjacent cells will not be equal to 8. So, write your code including those cases also.
# ##### Some points for higher dimension cases:
# 1. Think whether the number of adjacent cells for higher dimensions will be 8 or more (or less).
# 2. Observe that the dimension of each cell will not be $r*r$ for each case.
# ##### <u>Note</u>: Assume the pair $ (i,j) $ and $ (j,i) $ to be same. So write your code accordingly. For example, in 2-D space, we will count $ ((1,2), (4,5)) $ and $ ((4,5), (1,2)) $ only once.

# %% [markdown]
# ## Tasks TO DO:
#
# 1. Generate a set of $ 1000 $ random points in $ 2 $ dimensional space with coordinates ranging between 0 and 100.
# 2. For $ r = \{ 1, 2, \ldots, 10 \} $, divide the points into grid as shown.
#    - Show using matplotlib the various points using different colours.
#    - Find pairs and store them in a list/set $ A $
# 3. Do task 1 and 2 for $ d = 3, 4, 10, 50, 100 $ (except plotting) and store the results.
# (You can also plot for $ d = 3 $ but it is optional)

# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import product

# Function to find the norm
def euclidean_distance(point1, point2):
    return np.linalg.norm(point1 - point2)

# Function to find pair of points within given distance
def find_pairs_within_distance(points, r):
    n = len(points)
    cell_indices = np.floor(points / r).astype(int)
    cell_dict = {}

    for i, idx in enumerate(cell_indices):
        if tuple(idx) not in cell_dict:
            cell_dict[tuple(idx)] = []
        cell_dict[tuple(idx)].append(i)

    pairs = set()

    for i, point in enumerate(points):
        idx = cell_indices[i]
        neighbor_cells = np.array(np.meshgrid(*[range(i-1, i+2) for i in idx])).T.reshape(-1, len(idx))
        valid_neighbor_cells = neighbor_cells[np.all((0 <= neighbor_cells) & (neighbor_cells < np.ceil(100/r)), axis=1)]
        
        for cell in valid_neighbor_cells:
            if tuple(cell) in cell_dict:
                for idx in cell_dict[tuple(cell)]:
                    if idx != i and np.linalg.norm(point - points[idx]) < r:
                        pairs.add(tuple(sorted((tuple(point), tuple(points[idx])))))

    return pairs


# Function to generate random points in 2D space (float values)
def generate_random_points(num_points, min_val, max_val,dimension):
    points = np.random.uniform(min_val, max_val, size=(num_points, dimension))
    return points

# Function to plot the points and grid
def plot_points_with_grid(points, r):
    plt.figure(figsize=(35,20))
    plt.scatter(points[:, 0], points[:, 1], c=np.arange(len(points)), cmap='viridis')
    plt.colorbar(label='Point Index')
    plt.title('Scatter Plot of Points in 2D Space')
    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.grid(True)  # Show gridlines

    # Creating gridlines at a distance of r
    x_min, x_max = min(points[:, 0]), max(points[:, 0])
    y_min, y_max = min(points[:, 1]), max(points[:, 1])
    x_grid = np.arange(np.floor(x_min / r) * r, np.ceil(x_max / r) * r + r, r)  # Adjusted range for x-axis
    y_grid = np.arange(np.floor(y_min / r) * r, np.ceil(y_max / r) * r + r, r)  # Adjusted range for y-axis
    plt.xticks(x_grid)
    plt.yticks(y_grid)
    plt.show() # Display the plot
    return points

# Input parameters
num_points = 1000
min_val, max_val = 1.0, 100.0
distance_r = 1 # Set the distance for gridlines
dimension=2

# Generate random points in 2D space with float values
random_points = generate_random_points(num_points, min_val, max_val,dimension)
#print(random_points)

# Plotting the points and grid for 2D
if(dimension==2):
    points = plot_points_with_grid(random_points, distance_r)

# Find unique pairs of points within distance r
pairs_within_distance_r = find_pairs_within_distance(random_points, distance_r)
print("Pairs within distance r:")
for pair in pairs_within_distance_r:
    print(pair)  # Printing unique pairs of points
# Out:
# Pairs within distance r:
# ((87.3709836986107, 70.81052713567705), (88.18099206992561, 70.498863284364))
# ((96.79358518048468, 27.164162116558867), (97.54895806224857, 27.530657362811404))
# ((45.064575407021216, 88.17989530695073), (45.960067413904554, 88.01987161922749))
# ((86.45902497393492, 96.1392081893589), (87.03671426945594, 95.5277574540397))
# ((53.592209042559325, 2.852216734421979), (54.13229688923428, 2.7589512479089486))
# ((68.96990281068622, 18.491187421593494), (69.65475256936529, 18.986461393810554))
# ((40.9093321874962, 96.50227084980293), (41.26290089987162, 97.22051631913136))
# ((29.957774017232914, 79.11628320918277), (29.958300153459057, 79.48494751645599))
# ((73.8627744990683, 39.12178012291123), (74.08134400805632, 39.10442490128344))
# ((1.502836024939509, 23.511420954986654), (2.370356310066147, 23.064933874462273))
# ((78.19594943513113, 72.91022847668074), (78.7614399273833, 72.648682136454))
# ((53.250655597468885, 3.435164412552769), (53.592209042559325, 2.852216734421979))
# ((59.96285596884619, 10.583066630776933), (60.689469281909325, 10.461923121525379))
# ((82.10809542006584, 68.35494745443572), (82.35051158869824, 68.42701365586483))
# ((25.880060561580343, 89.5364390281308), (26.293549565977024, 89.51001600801385))
# ((33.38782546554916, 25.71687583237498), (34.145210527450104, 25.920413760492423))
# ((35.74341595080316, 20.012606061740136), (36.58831626396337, 20.37585428792869))
# ((35.51916640198132, 7.271933545726335), (36.014473758496074, 6.861482317331784))
# ((42.13956917646109, 86.97326826496275), (42.405419140221234, 86.24021223511748))
# ((10.245904534431158, 29.955066962351406), (10.984373072774735, 30.491446950966456))
# ((74.9262694889152, 13.72682447882364), (75.67956594140185, 14.050833587562195))
# ((66.00027806097756, 17.865938032219074), (66.28439308546828, 18.538065133274724))
# ((13.145836414048395, 78.70868325105974), (13.16455690802331, 78.20898267453187))
# ((4.650031031934013, 14.487039118646647), (4.7546411828256945, 14.513073527915486))
# ((41.413929890625845, 64.74617808398416), (41.47617374921502, 65.70247305713363))
# ((1.5239687675926423, 50.535676198325135), (2.248439165035296, 51.01519539093159))
# ((75.3412610642011, 61.808580738227796), (75.45890953134735, 62.0556414380823))
# ((71.26204141685916, 85.50193765083472), (72.20256649414083, 85.41441530055678))
# ((4.7546411828256945, 14.513073527915486), (4.805703920327054, 14.15030930635706))
# ((4.08659801436519, 93.01964888303687), (4.540710919894275, 92.17723515370385))
# ((1.4807039757506355, 12.230044717752591), (2.0731131321610254, 11.816404457965461))
# ((18.120120033777845, 69.31033018063503), (18.214608811856156, 70.17112385247866))
# ((73.60503422564953, 38.898475738984125), (74.08134400805632, 39.10442490128344))
# ((80.17041488889778, 31.75037820595141), (80.1957601483286, 31.706136400640094))
# ((38.388633730737595, 57.08375816609719), (38.64132953645612, 57.01963354073234))
# ((47.616920897572456, 37.40058917614597), (48.36454713292, 37.09552855306661))
# ((74.08134400805632, 39.10442490128344), (74.67610854001204, 39.327944267182666))
# ((16.29415608218051, 48.2359948604309), (16.43900477319718, 47.28973342703059))
# ((24.853391950140068, 6.284219366282489), (24.947952841891684, 6.085438020928247))
# ((61.442343894674906, 51.950989278672886), (61.72082566196968, 51.367236774695066))
# ((54.779477600049766, 26.896214150817553), (55.15146527149738, 27.064598265510636))
# ((44.921614877927894, 14.472120154647548), (45.055433721142684, 13.570189366244527))
# ((54.82850952274081, 19.497586314590006), (55.29096664492931, 19.36277632111696))
# ((81.99271046119661, 43.235444707181664), (82.01089386796636, 43.944981538030895))
# ((33.86389362952335, 90.33494013683173), (34.7015498934224, 89.83017898533006))
# ((36.014473758496074, 6.861482317331784), (36.50154391446746, 6.743280746699982))
# ((4.650031031934013, 14.487039118646647), (4.805703920327054, 14.15030930635706))
# ((16.29415608218051, 48.2359948604309), (16.33770696040175, 47.634311241461994))
# ((27.96395764538363, 82.88318382978963), (28.700733833332556, 82.44363682630751))
# ((31.962103558033913, 22.93046771655727), (32.544182729678454, 23.328314725537044))
# ((81.99675859193809, 15.981838245755615), (82.35171819033702, 16.619784899767865))
# ((43.205938295991125, 43.274307887384076), (43.46675914499764, 44.12597165743632))
# ((87.52535805195869, 64.45831612575739), (88.3698201798529, 64.65700123526648))
# ((75.10488575676446, 62.43197881181415), (75.3412610642011, 61.808580738227796))
# ((82.37439743288363, 84.91029150505491), (82.47445489964677, 85.5100661646029))
# ((76.01760166583338, 77.39078384840627), (76.2270736435966, 77.29442257916548))
# ((36.014473758496074, 6.861482317331784), (36.813935026288696, 6.315195763887813))
# ((44.646640767480896, 88.61847769064305), (45.064575407021216, 88.17989530695073))
# ((36.45548493903229, 32.135231073338396), (36.459663174718926, 31.393790813266865))
# ((43.385004853697666, 11.180404098386433), (43.73790300814936, 11.955413887568906))
# ((62.57712274132108, 1.0785062902235387), (62.873740746453656, 1.6689076554158928))
# ((44.30455557208503, 14.565763177065472), (44.921614877927894, 14.472120154647548))
# ((28.376366998309056, 71.37321624848002), (29.278679421242533, 71.61213843864638))
# ((33.69645742781689, 5.268117804520484), (34.35447072455094, 5.982972377548382))
# ((95.0313536169148, 66.32952164307878), (95.18905836532633, 66.9023618190306))
# ((46.71904173182863, 38.454648747981636), (47.61319052773002, 38.53754880529358))
# ((22.07122140274933, 61.9807100760081), (22.551591110271588, 62.671332004241734))
# ((27.842271090087344, 87.31902237660228), (28.534233601624447, 86.78814440898307))
# ((46.067918279304514, 45.143250532699035), (46.67286644320003, 45.77872975960942))
# ((82.35051158869824, 68.42701365586483), (82.84408968097465, 68.61577530744403))
# ((52.056134024044795, 2.4037813179254734), (52.41753441033694, 2.7218661236013184))
# ((22.183699557353048, 3.7213706026872435), (22.532704707112547, 4.137401101080275))
# ((60.661884515663544, 51.785643413179436), (61.442343894674906, 51.950989278672886))
# ((75.10488575676446, 62.43197881181415), (75.45890953134735, 62.0556414380823))
# ((80.85236256936331, 61.81626207638539), (81.22965304143762, 61.28190079492756))
# ((81.15726019420978, 42.82246582902333), (81.99271046119661, 43.235444707181664))
# ((43.73790300814936, 11.955413887568906), (44.177709942271605, 11.242326947257713))
# ((46.098589018449374, 23.18445482137793), (46.15332504900536, 22.222677695250724))
# ((73.8627744990683, 39.12178012291123), (74.67610854001204, 39.327944267182666))
# ((43.222303999655, 1.571467117016494), (43.58202163381366, 2.3133673113851243))
# ((86.75381420703721, 95.56074299722223), (87.67781107396458, 95.322176424168))
# ((97.7411140212147, 84.40309246694328), (98.2259031236069, 84.7210542760244))
# ((18.310745617282006, 25.724555967082278), (18.320395487182456, 25.307722048499006))
# ((11.891392795817527, 36.1326835387207), (12.627465465394696, 35.96630148393916))
# ((91.23837439186617, 82.12488857353479), (91.90201907754131, 82.82055027503706))
# ((93.88120233802172, 6.544640183958483), (94.10114156939208, 7.444567146195774))
# ((94.05150268089858, 13.798240785139381), (94.65490878223432, 14.320432610440207))
# ((27.77705136772191, 55.858018709340136), (28.350120841747525, 56.11099823478555))
# ((15.868043566136645, 92.14645462594666), (16.11912139410188, 92.44854163429387))
# ((22.823421958347573, 5.485642146763391), (23.524719200462762, 4.89008856666384))
# ((92.451265154931, 24.537037608943688), (92.99346672824585, 25.186197713103677))
# ((81.97822359680852, 25.211305832289398), (82.10884737257781, 24.928448176974037))
# ((66.5861147369708, 5.086379054137566), (66.80888251375927, 4.761560654210205))
# ((38.388633730737595, 57.08375816609719), (38.40185461897263, 56.86261673876967))
# ((84.18390535449271, 55.91625992847843), (84.42352006764969, 55.92913435299808))
# ((73.60503422564953, 38.898475738984125), (73.8627744990683, 39.12178012291123))
# ((55.29096664492931, 19.36277632111696), (55.53337805432137, 18.715808071588746))
# ((75.68868566372994, 56.11180495420259), (76.34358016165689, 55.601690547826266))
# ((3.823208296076783, 44.079242840091545), (4.326179343825156, 44.54406038377294))
# ((51.630850659496936, 61.668646936906924), (52.39685982413267, 61.74329502203119))
# ((51.36776815445743, 2.22538534336846), (52.056134024044795, 2.4037813179254734))
# ((82.35171819033702, 16.619784899767865), (82.6044142748116, 16.86933487887649))
# ((73.9960066898134, 69.45333754723876), (74.41428511139473, 69.1064399587059))
# ((57.115666511916906, 90.30255612106261), (57.74809181908516, 90.81049905212721))
# ((80.49118523843315, 59.73704955811517), (81.12788008537726, 59.78683664750408))
# ((86.75381420703721, 95.56074299722223), (87.03671426945594, 95.5277574540397))
# ((14.740974377970891, 39.14714991876048), (14.781076376307364, 38.91957166897791))
# ((43.385004853697666, 11.180404098386433), (44.177709942271605, 11.242326947257713))
# ((53.15250750909049, 29.979106851899793), (53.234303265376255, 29.600344789458433))
# ((26.45946076100928, 12.619354750543573), (26.928484113163027, 13.039237375815516))
# ((2.147534976843648, 13.295894749648516), (2.359792021773317, 13.650933202397871))
# ((8.191168848557819, 49.974725526315886), (8.53563586720391, 49.99106586371405))
# ((34.81029128439476, 35.47831018207214), (35.44298456716965, 35.314380162710265))
# ((86.45902497393492, 96.1392081893589), (86.75381420703721, 95.56074299722223))
# ((45.055433721142684, 13.570189366244527), (45.82184977163813, 13.88246708147697))
# ((36.50154391446746, 6.743280746699982), (36.813935026288696, 6.315195763887813))
# ((90.5275626815905, 74.41434494074333), (91.0925145216129, 74.33317087435013))
# ((5.914415010910359, 86.049263621717), (6.3358654420178375, 85.73727065502524))
# ((65.40214331039313, 2.174861252906973), (65.49261263590594, 1.268950068917691))
# ((20.524770228953667, 31.72468065530156), (20.88210570713418, 31.26118870532098))
# ((16.33770696040175, 47.634311241461994), (16.43900477319718, 47.28973342703059))
# ((84.42352006764969, 55.92913435299808), (85.3825724532551, 56.08789687966721))
# ((38.40185461897263, 56.86261673876967), (38.64132953645612, 57.01963354073234))
# ((82.10809542006584, 68.35494745443572), (82.84408968097465, 68.61577530744403))
# ((11.554091887091396, 78.7853198716171), (12.05103330104797, 78.3878539232491))
# ((87.22287653371076, 65.23569221182619), (87.52535805195869, 64.45831612575739))
# ((87.03671426945594, 95.5277574540397), (87.67781107396458, 95.322176424168))
# ((25.71053241946113, 24.289357330027293), (25.92440269954687, 23.54000775002411))
# ((59.88197648880665, 51.37936092573448), (60.661884515663544, 51.785643413179436))
# ((35.44298456716965, 35.314380162710265), (35.83089757848208, 35.05292952634783))
# ((53.67880920614177, 90.22135018255159), (53.73708215908156, 90.71445178408251))
# ((28.700733833332556, 82.44363682630751), (28.795336612773596, 82.10852530312575))
# ((60.89518717417507, 54.03088321700264), (61.62802469527889, 54.139768804221724))
# ((51.89377763179691, 34.347818950062475), (52.469447597382, 35.00023461742883))
# ((52.63905724790506, 29.995153860732042), (53.234303265376255, 29.600344789458433))
# ((3.234461411295074, 34.8265753353372), (4.108193114418661, 34.37966311736745))
# ((5.575038627466811, 39.38203019909249), (5.672320566419702, 39.23223907233117))
# ((47.58885320611955, 3.4700555304763188), (48.19480851241794, 3.7401767060706317))
# ((40.36643668906347, 51.354872083242455), (40.985559830560234, 50.93452571437191))
# ((15.69723549947146, 17.88751220147064), (16.30034220014081, 17.849849683415176))
# ((22.112689511481737, 83.89212670587469), (22.933351473612458, 83.83599884834551))
# ((79.95154051133979, 64.70106368117783), (80.65765986948946, 64.37910961304999))
# ((52.63905724790506, 29.995153860732042), (53.15250750909049, 29.979106851899793))
# ((48.913154589706906, 62.15322742094024), (49.101552300877735, 62.72516698990115))
